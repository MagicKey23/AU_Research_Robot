# %% [markdown]
# <a href="https://colab.research.google.com/github/MagicKey23/AU_Research_Robot/blob/main/aug_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Get System Detail**

# %%
# %cat /etc/lsb-release
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=18.04
# DISTRIB_CODENAME=bionic
# DISTRIB_DESCRIPTION="Ubuntu 18.04.5 LTS"

# %% [markdown]
# **Update System**

# %%
# !apt-get update
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [787 kB]
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:9 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# ...

# %%
# %pwd
# %cd /content/drive/MyDrive/aug_lab/
# Out:
# /content/drive/MyDrive/aug_lab

# %%
# !unzip "/content/drive/MyDrive/aug_lab/darknet.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: darknet/aug_datas/Extras Image/Irobot_data1317.jpg
#   inflating: darknet/aug_datas/Extras Image/Irobot_data1318.jpg
#   inflating: darknet/aug_datas/Extras Image/Irobot_data1319.jpg
#   inflating: darknet/aug_datas/Extras Image/Irobot_data1320.jpg
#   inflating: darknet/aug_datas/Extras Image/Irobot_data1321.jpg
#   inflating: darknet/aug_datas/Extras Image/Irobot_data1322.jpg
#   inflating: darknet/aug_datas/Extras Image/Irobot_data1323.jpg
#   inflating: darknet/aug_datas/Extras Image/Irobot_data1324.jpg
#   inflating: darknet/aug_datas/Extras Image/Irobot_data1325.jpg
#   inflating: darknet/aug_datas/Extras Image/Irobot_data1326.jpg
#   inflating: darknet/aug_datas/Extras Image/Irobot_data1327.jpg
#   inflating: darknet/aug_datas/Extras Image/Irobot_data1328.jpg
#   inflating: darknet/aug_datas/Extras Image/Irobot_data1329.jpg
#   inflating: darknet/aug_datas/Extras Image/Irobot_data1330.jpg
# ...

# %%
cd "/content/drive/MyDrive/aug_lab/darknet"
# Out:
# /content/drive/MyDrive/aug_lab/darknet

# %% [markdown]
# **Convert Dos file to Unix**

# %%
# !sudo apt install dos2unix
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 75 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,267 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 dos2unix amd64 7.3.4-3 [351 kB]
# Fetched 351 kB in 1s (402 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
# %pwd
# Out:
# '/content'

# %%
# !find . -type f -print0 | xargs -0 dos2unix
# Out:
# Streaming output truncated to the last 5000 lines.
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./aug_datas/Extras Image/Irobot_data892.jpg
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./aug_datas/Extras Image/Irobot_data893.jpg
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./aug_datas/Extras Image/Irobot_data894.jpg
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./aug_datas/Extras Image/Irobot_data895.jpg
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./aug_datas/Extras Image/Irobot_data896.jpg
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./aug_datas/Extras Image/Irobot_data897.jpg
# dos2unix: Binary symbol 0x00 found at line 1
# dos2unix: Skipping binary file ./aug_datas/Extras Image/Irobot_data898.jpg
# dos2unix: Binary symbol 0x00 found at line 1
# ...

# %%
# !chmod +x "./darknet"

# %%
# %pwd
# Out:
# '/content'

# %%
# !make
# Out:
# chmod +x *.sh

# %% [markdown]
# **Test default image**

# %%
# !./darknet detector test cfg/coco.data cfg/yolov4.cfg yolov4.weights data/person.jpg
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0

# %%
# !rm /content/drive/MyDrive/aug_lab/darknet/backup -r
# Out:
# rm: cannot remove '/content/drive/MyDrive/aug_lab/darknet/backup': No such file or directory

# %% [markdown]
# **Link backup file**

# %%
# !ln -s /content/drive/MyDrive/AU_Lab_weights/backup /content/drive/MyDrive/aug_lab/darknet
# Out:
# ln: failed to create symbolic link '/content/drive/MyDrive/aug_lab/darknet/backup': File exists

# %%
# %pwd
# %cd /content/drive/MyDrive/aug_lab/darknet
# !chmod +x "./darknet"
# Out:
# /content/drive/MyDrive/aug_lab/darknet

# %% [markdown]
# **Train Data**

# %%
# !./darknet detector train aug_datas/lab.data au_lab_yolov4.cfg yolov4-tiny.conv.29 -map -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.832840), count: 4, class_loss = 0.015318, iou_loss = 0.463726, total_loss = 0.479044
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.730770), count: 17, class_loss = 1.194571, iou_loss = 12.960736, total_loss = 14.155307
#  total_bbox = 376492, rewritten_bbox = 0.064809 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.841898), count: 5, class_loss = 0.059055, iou_loss = 0.411452, total_loss = 0.470507
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.734471), count: 10, class_loss = 0.700024, iou_loss = 6.764225, total_loss = 7.464250
#  total_bbox = 376507, rewritten_bbox = 0.064806 %
# ...

# %% [markdown]
# **resume train**

# %%
# !./darknet detector train aug_datas/lab.data au_lab_yolov4.cfg /content/drive/MyDrive/AU_Lab_weights/backup/au_lab_yolov4_last.weights -map -dont_show
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  Prepare additional network for mAP calculation...
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 12, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
# ...

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Tue Jul  5 18:20:05 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
